# %% [markdown]
# # Phase 12 Multi-Seed Validation
#
# **Instructions:**
# 1. Ensure your Colab runtime is set to GPU (Runtime > Change runtime type > Hardware accelerator > T4 GPU).
# 2. In the file browser on the left, click the **Upload** icon and upload phase12_colab_package.zip (NOT colab_data.zip).
# 3. Wait for the upload to finish 100%.
# 4. Run all cells below.

# %%
# !unzip -o phase12_colab_package.zip

# %%
# !python scripts/experiments/phase12_multiseed.py

# %%
# !zip -r phase12_results.zip artifacts/multiseed/ results/final/
from google.colab import files
files.download('phase12_results.zip')
